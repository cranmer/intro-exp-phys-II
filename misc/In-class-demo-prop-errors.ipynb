# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#For 3d plots
from mpl_toolkits.mplot3d import Axes3D

# %%
x0 = 1.
y0 = 3.
deltax=0.1
deltay=0.2
x = np.random.normal(x0,deltax,100000)
y = np.random.normal(y0,deltay,1000)

# %%
q = 1/x

# %%
q0=x0+y0
deltaq = np.sqrt( (deltax)**2 +  (deltay)**2 )
q0, deltaq
# Out:
# (4.0, 0.22360679774997899)

# %%
np.mean(q), np.std(q)
# Out:
# (3.9955545439046039, 0.22246982719803049)

# %%
np.max(q)
# Out:
# 12.50286803730439

# %%
#plt.hist(q, bins=np.linspace(0,3,50))
plt.hist(q, bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  3.00000000e+00,   8.00000000e+00,   3.00000000e+00,
#           1.80000000e+01,   1.80000000e+01,   4.20000000e+01,
#           6.90000000e+01,   1.43000000e+02,   2.37000000e+02,
#           3.62000000e+02,   5.21000000e+02,   7.27000000e+02,
#           1.08500000e+03,   1.45000000e+03,   1.96600000e+03,
#           2.53000000e+03,   3.00200000e+03,   3.86400000e+03,
#           4.50800000e+03,   5.12300000e+03,   5.68900000e+03,
#           6.17100000e+03,   6.43100000e+03,   6.41100000e+03,
#           6.39400000e+03,   6.40300000e+03,   5.97300000e+03,
#           5.48300000e+03,   5.00300000e+03,   4.29400000e+03,
#           3.57100000e+03,   2.96600000e+03,   2.45100000e+03,
#           1.95300000e+03,   1.48400000e+03,   1.10700000e+03,
#           8.20000000e+02,   5.07000000e+02,   4.38000000e+02,
#           2.55000000e+02,   1.84000000e+02,   1.17000000e+02,
# ...

# %%
import seaborn as sns

# %%
g = sns.JointGrid(x,q)
g.set_axis_labels('x','q')
g = g.plot_joint(plt.scatter, alpha=0.5)
g = g.plot_marginals(sns.distplot)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
g = sns.JointGrid(q,x)
g.set_axis_labels('q','x')
g = g.plot_joint(plt.scatter, alpha=0.5)
g = g.plot_marginals(sns.distplot)
# Out:
# <img src="data:image/png;base64,..." width="600">
